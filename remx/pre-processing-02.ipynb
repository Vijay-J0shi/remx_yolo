# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;" align=center>Labels To XYWH</h3>

# %%
import sys

sys.path.append("../remx/utils")

from images import labels_dir_xyxy2xywh

# %%
train_labels_dir = "../datasets/farm_animals/train/labels"
val_labels_dir = "../datasets/farm_animals/val/labels"
test_labels_dir = "../datasets/farm_animals/test/labels"

# %%
labels_dir_xyxy2xywh(train_labels_dir)
# Out:
# Updated coordinates in 6ce84debfa1c2c20.txt
# Updated coordinates in d574ddfe57404998.txt
# Updated coordinates in 343f2e7b049715bf.txt
# Updated coordinates in b4fe308100e4b610.txt
# Updated coordinates in 48369714f4029298.txt
# Updated coordinates in 14ba6b645858f97f.txt
# Updated coordinates in 09c5418e3c038074.txt
# Updated coordinates in 2a7925254920c310.txt
# Updated coordinates in 3b76f96a50cc5591.txt
# Updated coordinates in a7e296001dd352bd.txt
# Updated coordinates in 215c2b2539168c68.txt
# Updated coordinates in bc5b499eeb7cd393.txt
# Updated coordinates in 821602a7c699166d.txt
# Updated coordinates in adba898a5e58eb7a.txt
# Updated coordinates in 2143f2d190eba5ac.txt
# Updated coordinates in 1f7b72d52c0aeed5.txt
# Updated coordinates in 75eab8779dcbbe41.txt
# Updated coordinates in c01abced24481542.txt
# Updated coordinates in e5f2a786ce5e8657.txt
# Updated coordinates in 79111051ba7d88e0.txt
# Updated coordinates in b39a328cfa5c7c68.txt
# ...

# %%
labels_dir_xyxy2xywh(val_labels_dir)
# Out:
# Updated coordinates in 110cbd6a3caa5bd0.txt
# Updated coordinates in 736e94538854513c.txt
# Updated coordinates in 6ed23982bf81cca0.txt
# Updated coordinates in 05427c05716ac2bc.txt
# Updated coordinates in 173a992d5facc22b.txt
# Updated coordinates in 80dc7656edd319fb.txt
# Updated coordinates in 3f660957d4e3b81d.txt
# Updated coordinates in f91998908ca5ef9f.txt
# Updated coordinates in 3129bf59d6643fbf.txt
# Updated coordinates in 5663c431e579e081.txt
# Updated coordinates in 7c38f2af4113c353.txt
# Updated coordinates in 68c183ec30152630.txt
# Updated coordinates in 6bc06551b9935f11.txt
# Updated coordinates in 2f02c3145d1c2dfc.txt
# Updated coordinates in 99e1189fb9150f80.txt
# Updated coordinates in 47f6b3e17ac7d357.txt
# Updated coordinates in 0006476c7a10ac38.txt
# Updated coordinates in e4bb9f0e0c6dbb06.txt
# Updated coordinates in 20901e9027511596.txt
# Updated coordinates in 8fb7a66faa37bbb0.txt
# Updated coordinates in 03dc5b0ca8e42457.txt
# ...

# %%
labels_dir_xyxy2xywh(test_labels_dir)
# Out:
# Updated coordinates in ad954d00123bee02.txt
# Updated coordinates in 7e221ad9496b1c7c.txt
# Updated coordinates in 3864d0d4ae4707da.txt
# Updated coordinates in 0392fe901a316b0f.txt
# Updated coordinates in 021bfb005c123603.txt
# Updated coordinates in 38699b3aaebc3491.txt
# Updated coordinates in 9eeb0e03d811cb97.txt
# Updated coordinates in d5c53c2f25519448.txt
# Updated coordinates in 7c0b3d220f16b74c.txt
# Updated coordinates in 35a86249723da96b.txt
# Updated coordinates in 0dc2dbb29123b2de.txt
# Updated coordinates in 800226a3e0572c7b.txt
# Updated coordinates in 5c41e3cab9c34caa.txt
# Updated coordinates in 8de56bbf7d4ff1db.txt
# Updated coordinates in e6be4b1bac13fd3b.txt
# Updated coordinates in 1aa33720229e5697.txt
# Updated coordinates in 80c1a09275935086.txt
# Updated coordinates in 43917c747a83f93f.txt
# Updated coordinates in 1bd1d8bd377fb127.txt
# Updated coordinates in 22e21c8c547f5f46.txt
# Updated coordinates in 084599bb84e38f34.txt
# ...
