# %%
import sys

sys.path.append("../remx/utils")

from images_predict_fn import draw_max_confidence_img

# %%
img = "./tests/fbde545860c21b29.jpg"
draw_img = draw_max_confidence_img(original_img=img, max_confidence_coordinate=(249, 211, 387, 476))

# %%
import cv2
import matplotlib.pyplot as plt

# Convert BGR image to RGB for displaying with matplotlib
img_rgb = cv2.cvtColor(draw_img, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(img_rgb)
plt.axis("off")
plt.show()
