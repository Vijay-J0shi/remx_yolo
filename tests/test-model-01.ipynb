# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;" align="center">Model Test 01</h3>

# %%
import sys
sys.path.append("../remx/utils")

from images_predict_fn import predict_images

# %%
# parameters

MODEL = "../models/model.onnx"
IMAGE = './datasets'

# %%
prediction = predict_images(MODEL, IMAGE)

# %%
prediction["axis-deer"]["./datasets/axis-deer/test-axis-deer.jpg"]
# Out:
# {'img': array([[[114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114],
#          ...,
#          [114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114]],
#
#         [[114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114],
#          ...,
#          [114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114]],
#
#         [[114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114],
#          ...,
#          [114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114]],
#
#         ...,
#
#         [[114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114],
#          ...,
#          [114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114]],
#
#         [[114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114],
#          ...,
#          [114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114]],
#
#         [[114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114],
#          ...,
#          [114, 114, 114],
#          [114, 114, 114],
#          [114, 114, 114]]], dtype=uint8),
#  'coordiante': [(337, 394, 520, 471),
#   (338, 394, 516, 472),
#   (338, 392, 520, 469)],
#  'labels': 'axis-deer'}

# %%
img = prediction["axis-deer"]["./datasets/axis-deer/test-axis-deer.jpg"]["img"]

# %%
from matplotlib import pyplot as plt
import cv2

# Display the original image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
