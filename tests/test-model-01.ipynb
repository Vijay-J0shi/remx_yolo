# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;" align="center">Model Test 01</h3>

# %%
import sys
sys.path.append("../remx/utils")

from images_predict_fn import predict_images

# %%
# parameters

MODEL = "../models/model.onnx"
IMAGE = './datasets'

# %%
prediction = predict_images(MODEL, IMAGE)

# %%
prediction[0]["./datasets/elephant/test-elephant.jpg"]
# Out:
# {'img': array([[[142, 194, 154],
#          [142, 194, 154],
#          [142, 195, 155],
#          ...,
#          [ 50,  68,  67],
#          [ 57,  75,  74],
#          [ 62,  80,  79]],
#
#         [[142, 194, 154],
#          [142, 194, 154],
#          [142, 195, 155],
#          ...,
#          [ 57,  75,  74],
#          [ 62,  80,  79],
#          [ 65,  83,  82]],
#
#         [[142, 194, 154],
#          [142, 194, 154],
#          [142, 194, 154],
#          ...,
#          [ 69,  85,  84],
#          [ 69,  85,  84],
#          [ 68,  84,  83]],
#
#         ...,
#
#         [[128, 206, 145],
#          [125, 205, 144],
#          [122, 204, 145],
#          ...,
#          [161, 207, 131],
#          [161, 207, 131],
#          [161, 207, 131]],
#
#         [[129, 210, 147],
#          [128, 209, 146],
#          [125, 208, 146],
#          ...,
#          [164, 207, 132],
#          [164, 207, 132],
#          [163, 206, 131]],
#
#         [[131, 212, 149],
#          [131, 212, 149],
#          [127, 210, 148],
#          ...,
#          [165, 208, 133],
#          [164, 207, 132],
#          [164, 207, 132]]], dtype=uint8),
#  'inverse_coordiante': [(1684, 1054, 4557, 3098)],
#  'labels': [1]}

# %%
img = prediction[0]["./datasets/elephant/test-elephant.jpg"]["img"]

# %%
from matplotlib import pyplot as plt
import cv2

# Display the original image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
